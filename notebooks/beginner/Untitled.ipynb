# %%
live = input("Where do you live?")
print("You live in ", live,".")
# Out:
# Where do you live?los angeles
# You live in  los angeles .

# %%
print("\n Where is ", live)
place = input()
print("Oh! so it's in", place, ".")
# Out:
#  Where is  los angeles
# africa
# Oh! so it's in africa .

# %% [markdown]
# #### List the installed packages

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Ashoo\Miniconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# WARNING: Logging before flag parsing goes to stderr.
# W0728 20:58:54.830278  4380 _import_c_extension.py:32] This caffe2 python run does not have GPU support. Will run in CPU only mode.
# C:\Users\Ashoo\Miniconda3\lib\site-packages\nltk\twitter\__init__.py:22: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   "The twython library has not been installed. "
# C:\Users\Ashoo\Miniconda3\lib\site-packages\rasa_core_sdk\__init__.py:12: UserWarning: The 'rasa_core_sdk' package has been renamed. You should change your imports to use 'rasa_sdk' instead.
#   UserWarning,
# :0: UserWarning: You do not have a working installation of the service_identity module: 'cannot import name 'verify_ip_address''.  Please install it from <https://pypi.python.org/pypi/service_identity> and make sure all of its dependencies are satisfied.  Without the service_identity module, Twisted can perform only rudimentary TLS client hostname verification.  Many valid certificate/hostname mappings may be rejected.
# C:\Users\Ashoo\Miniconda3\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# IPython             certifi             mmap                speech_recognition
# OpenSSL             cffi                mmapfile            sphinx
# PIL                 cgi                 mmsystem            spyder
# PyQt5               cgitb               mock                spyder_breakpoints
# __future__          chardet             modulefinder        spyder_io_dcm
# _ast                chunk               more_itertools      spyder_io_hdf5
# _asyncio            click               msgpack             spyder_kernels
# _bisect             cloudpickle         msgpack_numpy       spyder_profiler
# _blake2             clyent              msilib              spyder_pylint
# _bootlocale         cmath               msvcrt              sqlite3
# _bz2                cmd                 multiprocessing     sre_compile
# _cffi_backend       code                murmurhash          sre_constants
# _codecs             codecs              nbconvert           sre_parse
# _codecs_cn          codeop              nbformat            srsly
# _codecs_hk          collections         netbios             ssl
# _codecs_iso2022     colorama            netrc               sspi
# _codecs_jp          colorclass          networkx            sspicon
# _codecs_kr          coloredlogs         nltk                stat
# _codecs_tw          colorhash           nntplib             statistics
# _collections        colorsys            notebook            statsmodels
# _collections_abc    commctrl            nt                  storemagic
# _compat_pickle      compileall          ntpath              string
# _compression        concurrent          ntsecuritycon       stringprep
# _csv                conda               nturl2path          struct
# _ctypes             conda_env           numbers             subprocess
# _ctypes_test        configargparse      numpy               sunau
# _datetime           configparser        numpydoc            symbol
# _decimal            constantly          odbc                sympyprinting
# _distutils_findvs   contextlib          olefile             symtable
# _dummy_thread       copy                opcode              sys
# _elementtree        copyreg             operator            sysconfig
# _functools          crypt               optparse            tabnanny
# _hashlib            cryptography        os                  tabulate
# _heapq              cssselect           packaging           tarfile
# _imp                csv                 palettable          telegram
# _io                 ctypes              pandas              telnetlib
# _json               curses              pandocfilters       tempfile
# _locale             cwp                 parsel              tensorboard
# _lsprof             cycler              parser              tensorflow
# _lzma               cymem               parso               tensorflow_estimator
# _markupbase         cythonmagic         past                termcolor
# _md5                cytoolz             pathlib             terminado
# _msi                datetime            patsy               terminaltables
# _multibytecodec     dateutil            pdb                 test
# _multiprocessing    dbi                 perfmon             test_data
# _nsis               dbm                 pickle              test_pycosat
# _opcode             dde                 pickleshare         test_regex
# _operator           decimal             pickletools         testpath
# _osx_support        decorator           pika                tests
# _overlapped         defusedxml          pip                 textwrap
# _pickle             descartes           pipes               thinc
# _pydecimal          difflib             pkg_resources       this
# _pyio               dill                pkgutil             threading
# _pyrsistent_version dis                 plac                time
# _pytest             distutils           plac_core           timeit
# _random             docopt              plac_ext            timer
# _regex              doctest             plac_tk             tkinter
# _regex_core         docutils            platform            tlz
# _ruamel_yaml        dot_parser          plistlib            token
# _sha1               dummy_threading     plotnine            tokenize
# _sha256             easy_install        pluggy              toolz
# _sha3               email               poplib              torch
# _sha512             en_core_web_sm      posixpath           torchvision
# _signal             encodings           pprint              tornado
# _sitebuiltins       engineio            preshed             tqdm
# _socket             ensurepip           profile             trace
# _sqlite3            entrypoints         prometheus_client   traceback
# _sre                enum                prompt_toolkit      tracemalloc
# _ssl                errno               pstats              traitlets
# _stat               examples            psutil              tty
# _string             fakeredis           ptr                 turtle
# _strptime           faulthandler        pty                 turtledemo
# _struct             fbmessenger         pvectorc            twilio
# _symtable           filecmp             py                  twisted
# _system_path        fileinput           py_compile          typed_ast
# _testbuffer         flask               pyasn1              types
# _testcapi           flask_cors          pyasn1_modules      typing
# _testconsole        fnmatch             pyclbr              tzlocal
# _testimportmultiple formatter           pycodestyle         ujson
# _testmultiphase     fractions           pycosat             unicodedata
# _thread             ftplib              pycparser           unittest
# _threading_local    functools           pycrfsuite          urllib
# _tkinter            future              pydispatch          urllib3
# _tracemalloc        gast                pydoc               uu
# _warnings           gc                  pydoc_data          uuid
# _weakref            genericpath         pydot               venv
# _weakrefset         gensim              pyexpat             w3lib
# _win32sysloader     getopt              pyflakes            warnings
# _winapi             getpass             pygments            wasabi
# _winxptheme         gettext             pykwalify           watermark
# _yaml               gevent              pylab               wave
# abc                 glob                pylint              wcwidth
# absl                graphviz            pymongo             weakref
# adodbapi            gridfs              pyparsing           webbrowser
# afxres              grpc                pyreadline          webencodings
# aifc                gzip                pyrsistent          webexteamssdk
# alabaster           h5py                pytest              websocket
# anaconda_navigator  hamcrest            pytest_twisted      werkzeug
# antigravity         hashlib             pythoncom           wheel
# appdirs             heapq               pytz                widgetsnbextension
# apscheduler         hmac                pywin               win2kras
# argparse            html                pywin32_testutil    win32api
# array               html5lib            pywintypes          win32clipboard
# asn1crypto          http                qtawesome           win32com
# ast                 humanfriendly       qtconsole           win32con
# astor               hyperlink           qtpy                win32console
# astroid             idlelib             queue               win32cred
# async_generator     idna                queuelib            win32crypt
# asynchat            imageio             quopri              win32cryptcon
# asyncio             imagesize           random              win32ctypes
# asyncore            imaplib             rasa_core_sdk       win32event
# atexit              imghdr              rasa_sdk            win32evtlog
# atomicwrites        imp                 rasutil             win32evtlogutil
# attr                importlib           re                  win32file
# audioop             incremental         readline            win32gui
# automat             inspect             redis               win32gui_struct
# autoreload          io                  regcheck            win32help
# babel               ipaddress           regex               win32inet
# backcall            ipykernel           regutil             win32inetcon
# base64              ipykernel_launcher  reprlib             win32job
# bcrypt              ipython_genutils    requests            win32lz
# bdb                 ipywidgets          requests_toolbelt   win32net
# binascii            isapi               rlcompleter         win32netcon
# binhex              isort               rmagic              win32pdh
# binstar_client      itertools           rocketchat_API      win32pdhquery
# bisect              itsdangerous        rope                win32pdhutil
# bleach              jedi                ruamel_yaml         win32pipe
# blis                jinja2              runpy               win32print
# boruta              jmespath            s3transfer          win32process
# boto                json                sanic_jwt           win32profile
# boto3               jsonpickle          sched               win32ras
# botocore            jsonschema          scipy               win32rcparser
# brain_argparse      jupyter             scrapy              win32security
# brain_attrs         jupyter_client      scripts             win32service
# brain_builtin_inference jupyter_console     seaborn             win32serviceutil
# brain_collections   jupyter_core        secrets             win32timezone
# brain_curses        jwt                 select              win32trace
# brain_dateutil      kafka               selectors           win32traceutil
# brain_fstrings      keras_applications  selenium            win32transaction
# brain_functools     keras_preprocessing send2trash          win32ts
# brain_gi            keyring             service_identity    win32ui
# brain_hashlib       keyword             servicemanager      win32uiole
# brain_http          kiwisolver          setuptools          win32verstamp
# brain_io            lazy_object_proxy   shelve              win32wnet
# brain_mechanize     lib2to3             shlex               win_inet_pton
# brain_multiprocessing libfuturize         shutil              wincertstore
# brain_namedtuple_enum libpasteurize       signal              winerror
# brain_nose          linecache           simplejson          winioctlcon
# brain_numpy         locale              sip                 winnt
# brain_pkg_resources logging             sipconfig           winperf
# brain_pytest        lxml                sipdistutils        winpty
# brain_qt            lzma                site                winreg
# brain_random        macpath             six                 winsound
# brain_re            macurl2path         sklearn             winxpgui
# brain_six           mailbox             sklearn_crfsuite    winxptheme
# brain_ssl           mailcap             slackclient         wrapt
# brain_subprocess    markdown            smart_open          wsgiref
# brain_threading     markupsafe          smtpd               xdrlib
# brain_typing        marshal             smtplib             xml
# brain_uuid          math                sndhdr              xmlrpc
# brewer2mpl          matplotlib          snowballstemmer     xxsubtype
# bs4                 mccabe              socket              yaml
# bson                menuinst            socketio            zipapp
# builtins            mglearn             socketserver        zipfile
# bz2                 mimetypes           socks               zipimport
# cProfile            mistune             sockshandler        zlib
# caffe2              mizani              sortedcontainers    zmq
# calendar            mkl_fft             soupsieve           zope
# category_encoders   mkl_random          spacy
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# absl-py                       0.7.1
# alabaster                     0.7.12
# anaconda-client               1.7.2
# anaconda-navigator            1.9.7
# appdirs                       1.4.3
# APScheduler                   3.6.1
# asn1crypto                    0.24.0
# astor                         0.8.0
# astroid                       2.2.5
# async-generator               1.10
# atomicwrites                  1.3.0
# attrs                         19.1.0
# Automat                       0.7.0
# Babel                         2.7.0
# backcall                      0.1.0
# bcrypt                        3.1.6
# beautifulsoup4                4.7.1
# bleach                        3.1.0
# blis                          0.2.4
# Boruta                        0.1.5
# boto                          2.49.0
# boto3                         1.9.138
# botocore                      1.12.138
# brewer2mpl                    1.4.1
# category-encoders             1.3.0
# certifi                       2019.3.9
# cffi                          1.12.3
# chardet                       3.0.4
# Click                         7.0
# cloudpickle                   1.2.1
# clyent                        1.2.2
# colorama                      0.4.1
# colorclass                    2.2.0
# coloredlogs                   10.0
# colorhash                     1.0.2
# conda                         4.6.14
# ConfigArgParse                0.14.0
# constantly                    15.1.0
# cryptography                  2.7
# cssselect                     1.0.3
# cycler                        0.10.0
# cymem                         1.31.2
# cytoolz                       0.9.0.1
# decorator                     4.4.0
# defusedxml                    0.6.0
# descartes                     1.1.0
# dill                          0.2.9
# docopt                        0.6.2
# docutils                      0.14
# en-core-web-sm                2.1.0
# entrypoints                   0.3
# fakeredis                     1.0.3
# fbmessenger                   6.0.0
# Flask                         1.1.1
# Flask-Cors                    3.0.8
# future                        0.17.1
# gast                          0.2.2
# gensim                        3.7.2
# gevent                        1.4.0
# graphviz                      0.10.1
# greenlet                      0.4.15
# grpcio                        1.22.0
# h5py                          2.9.0
# html5lib                      1.0.1
# humanfriendly                 4.18
# hyperlink                     17.3.1
# idna                          2.8
# imageio                       2.5.0
# imagesize                     1.1.0
# incremental                   17.5.0
# ipykernel                     5.1.1
# ipython                       7.5.0
# ipython-genutils              0.2.0
# ipywidgets                    7.4.2
# isort                         4.3.21
# itsdangerous                  1.1.0
# jedi                          0.13.3
# Jinja2                        2.10.1
# jmespath                      0.9.4
# jsonpickle                    1.2
# jsonschema                    3.0.1
# jupyter                       1.0.0
# jupyter-client                5.2.4
# jupyter-console               6.0.0
# jupyter-core                  4.4.0
# kafka-python                  1.4.6
# Keras-Applications            1.0.8
# Keras-Preprocessing           1.1.0
# keyring                       19.0.2
# kiwisolver                    1.1.0
# lazy-object-proxy             1.4.1
# lxml                          4.3.3
# Markdown                      3.1.1
# MarkupSafe                    1.1.1
# matplotlib                    3.0.3
# mccabe                        0.6.1
# menuinst                      1.4.16
# mglearn                       0.1.7
# mistune                       0.8.4
# mizani                        0.5.4
# mkl-fft                       1.0.10
# mkl-random                    1.0.2
# mock                          3.0.5
# more-itertools                7.0.0
# msgpack                       0.5.6
# msgpack-numpy                 0.4.4.2
# murmurhash                    0.28.0
# nbconvert                     5.5.0
# nbformat                      4.4.0
# networkx                      2.3
# nltk                          3.4.1
# notebook                      5.7.8
# numpy                         1.16.2
# numpydoc                      0.9.1
# olefile                       0.46
# packaging                     19.0
# palettable                    3.1.1
# pandas                        0.24.2
# pandocfilters                 1.4.2
# parsel                        1.5.1
# parso                         0.4.0
# patsy                         0.5.1
# pickleshare                   0.7.5
# pika                          1.0.1
# Pillow                        6.0.0
# pip                           19.1.1
# plac                          0.9.6
# plotnine                      0.5.1
# pluggy                        0.9.0
# preshed                       1.0.1
# prometheus-client             0.6.0
# prompt-toolkit                2.0.9
# protobuf                      3.9.0
# psutil                        5.6.2
# py                            1.8.0
# pyasn1                        0.4.4
# pyasn1-modules                0.2.4
# pycodestyle                   2.5.0
# pycosat                       0.6.3
# pycparser                     2.19
# PyDispatcher                  2.0.5
# pydot                         1.4.1
# pyflakes                      2.1.1
# Pygments                      2.4.2
# PyHamcrest                    1.9.0
# PyJWT                         1.7.1
# pykwalify                     1.7.0
# pylint                        2.3.1
# pymongo                       3.8.0
# pyOpenSSL                     19.0.0
# pyparsing                     2.4.0
# PyQt5                         5.12.3
# PyQt5-sip                     4.19.18
# PyQtWebEngine                 5.12.1
# pyreadline                    2.1
# pyrsistent                    0.14.11
# PySocks                       1.7.0
# pytest                        4.5.0
# pytest-runner                 4.4
# pytest-twisted                1.10
# python-crfsuite               0.9.6
# python-dateutil               2.8.0
# python-engineio               3.8.2.post1
# python-socketio               4.2.0
# python-telegram-bot           11.1.0
# pytz                          2019.1
# pywin32                       223
# pywin32-ctypes                0.2.0
# pywinpty                      0.5.5
# PyYAML                        5.1
# pyzmq                         18.0.0
# QtAwesome                     0.5.7
# qtconsole                     4.5.1
# QtPy                          1.6.0
# queuelib                      1.5.0
# rasa-sdk                      1.1.0
# redis                         3.2.1
# regex                         2018.7.11
# requests                      2.22.0
# requests-toolbelt             0.9.1
# rocketchat-API                0.6.34
# rope                          0.14.0
# ruamel-yaml                   0.15.46
# ruamel.yaml                   0.15.100
# s3transfer                    0.2.0
# sanic-jwt                     1.3.2
# scikit-learn                  0.20.3
# scipy                         1.2.1
# Scrapy                        1.6.0
# seaborn                       0.9.0
# selenium                      3.141.0
# Send2Trash                    1.5.0
# service-identity              17.0.0
# setuptools                    41.0.1
# simplejson                    3.16.0
# six                           1.12.0
# sklearn-crfsuite              0.3.6
# slackclient                   1.3.2
# smart-open                    1.8.3
# snowballstemmer               1.9.0
# sortedcontainers              2.1.0
# soupsieve                     1.8
# spacy                         2.0.12
# SpeechRecognition             3.8.1
# Sphinx                        2.1.2
# sphinxcontrib-applehelp       1.0.1
# sphinxcontrib-devhelp         1.0.1
# sphinxcontrib-htmlhelp        1.0.2
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.2
# sphinxcontrib-serializinghtml 1.1.3
# spyder                        3.3.6
# spyder-kernels                0.5.1
# srsly                         0.0.6
# statsmodels                   0.9.0
# tabulate                      0.8.3
# tensorboard                   1.13.1
# tensorflow                    1.13.2
# tensorflow-estimator          1.13.0
# termcolor                     1.1.0
# terminado                     0.8.2
# terminaltables                3.1.0
# testpath                      0.4.2
# thinc                         6.10.3
# toolz                         0.9.0
# torch                         1.0.1
# torchvision                   0.2.2.post3
# tornado                       6.0.2
# tqdm                          4.32.1
# traitlets                     4.3.2
# twilio                        6.29.1
# Twisted                       19.2.0
# typed-ast                     1.4.0
# tzlocal                       2.0.0
# ujson                         1.35
# urllib3                       1.24.2
# w3lib                         1.20.0
# wasabi                        0.2.2
# watermark                     1.8.1
# wcwidth                       0.1.7
# webencodings                  0.5.1
# webexteamssdk                 1.1.1
# websocket-client              0.54.0
# Werkzeug                      0.15.5
# wheel                         0.33.4
# widgetsnbextension            3.4.2
# win-inet-pton                 1.1.0
# wincertstore                  0.2
# wrapt                         1.10.11
# zope.interface                4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# absl-py                       0.7.1
# alabaster                     0.7.12
# anaconda-client               1.7.2
# anaconda-navigator            1.9.7
# appdirs                       1.4.3
# APScheduler                   3.6.1
# asn1crypto                    0.24.0
# astor                         0.8.0
# astroid                       2.2.5
# async-generator               1.10
# atomicwrites                  1.3.0
# attrs                         19.1.0
# Automat                       0.7.0
# Babel                         2.7.0
# backcall                      0.1.0
# bcrypt                        3.1.6
# beautifulsoup4                4.7.1
# bleach                        3.1.0
# Boruta                        0.1.5
# boto                          2.49.0
# boto3                         1.9.138
# botocore                      1.12.138
# brewer2mpl                    1.4.1
# category-encoders             1.3.0
# certifi                       2019.6.16
# cffi                          1.12.3
# chardet                       3.0.4
# Click                         7.0
# cloudpickle                   1.2.1
# clyent                        1.2.2
# colorama                      0.4.1
# colorclass                    2.2.0
# coloredlogs                   10.0
# colorhash                     1.0.2
# conda                         4.7.10
# conda-package-handling        1.3.11
# ConfigArgParse                0.14.0
# constantly                    15.1.0
# cryptography                  2.7
# cssselect                     1.0.3
# cycler                        0.10.0
# cymem                         1.31.2
# cytoolz                       0.9.0.1
# decorator                     4.4.0
# defusedxml                    0.6.0
# descartes                     1.1.0
# dill                          0.2.9
# docopt                        0.6.2
# docutils                      0.14
# en-core-web-sm                2.1.0
# entrypoints                   0.3
# fakeredis                     1.0.3
# fbmessenger                   6.0.0
# Flask                         1.1.1
# Flask-Cors                    3.0.8
# future                        0.17.1
# gast                          0.2.2
# gensim                        3.7.2
# gevent                        1.4.0
# graphviz                      0.10.1
# greenlet                      0.4.15
# grpcio                        1.22.0
# h5py                          2.9.0
# html5lib                      1.0.1
# humanfriendly                 4.18
# hyperlink                     19.0.0
# idna                          2.8
# imageio                       2.5.0
# imagesize                     1.1.0
# importlib-metadata            0.17
# incremental                   17.5.0
# ipykernel                     5.1.1
# ipython                       7.6.1
# ipython-genutils              0.2.0
# ipywidgets                    7.5.0
# isort                         4.3.21
# itsdangerous                  1.1.0
# jedi                          0.13.3
# Jinja2                        2.10.1
# jmespath                      0.9.4
# joblib                        0.13.2
# jsonpickle                    1.2
# jsonschema                    3.0.1
# jupyter                       1.0.0
# jupyter-client                5.3.1
# jupyter-console               6.0.0
# jupyter-core                  4.5.0
# kafka-python                  1.4.6
# Keras-Applications            1.0.8
# Keras-Preprocessing           1.1.0
# keyring                       19.0.2
# kiwisolver                    1.1.0
# lazy-object-proxy             1.4.1
# libarchive-c                  2.8
# lightgbm                      2.2.1
# lxml                          4.3.4
# Markdown                      3.1.1
# MarkupSafe                    1.1.1
# matplotlib                    3.1.0
# mccabe                        0.6.1
# menuinst                      1.4.16
# mglearn                       0.1.7
# mistune                       0.8.4
# mizani                        0.5.4
# mkl-fft                       1.0.12
# mkl-random                    1.0.2
# mkl-service                   2.0.2
# mock                          3.0.5
# more-itertools                7.0.0
# msgpack                       0.5.6
# msgpack-numpy                 0.4.4.2
# murmurhash                    0.28.0
# nbconvert                     5.5.0
# nbformat                      4.4.0
# networkx                      2.3
# nltk                          3.4.4
# notebook                      6.0.0
# numpy                         1.16.4
# numpydoc                      0.9.1
# olefile                       0.46
# packaging                     19.0
# palettable                    3.1.1
# pandas                        0.24.2
# pandocfilters                 1.4.2
# parsel                        1.5.1
# parso                         0.5.0
# patsy                         0.5.1
# pickleshare                   0.7.5
# pika                          1.0.1
# Pillow                        6.1.0
# pip                           19.1.1
# plac                          0.9.6
# plotnine                      0.5.1
# pluggy                        0.12.0
# preshed                       1.0.1
# prometheus-client             0.7.1
# prompt-toolkit                2.0.9
# protobuf                      3.9.0
# psutil                        5.6.3
# py                            1.8.0
# pyasn1                        0.4.5
# pyasn1-modules                0.2.4
# pycodestyle                   2.5.0
# pycosat                       0.6.3
# pycparser                     2.19
# PyDispatcher                  2.0.5
# pydot                         1.4.1
# pyflakes                      2.1.1
# Pygments                      2.4.2
# PyHamcrest                    1.9.0
# PyJWT                         1.7.1
# pykwalify                     1.7.0
# pylint                        2.3.1
# pymongo                       3.8.0
# pyOpenSSL                     19.0.0
# pyparsing                     2.4.0
# PyQt5                         5.12.3
# PyQt5-sip                     4.19.18
# PyQtWebEngine                 5.12.1
# pyreadline                    2.1
# pyrsistent                    0.14.11
# PySocks                       1.7.0
# pytest                        5.0.1
# pytest-runner                 4.4
# pytest-twisted                1.10
# python-crfsuite               0.9.6
# python-dateutil               2.8.0
# python-engineio               3.8.2.post1
# python-socketio               4.2.0
# python-telegram-bot           11.1.0
# pytz                          2019.1
# pywin32                       223
# pywin32-ctypes                0.2.0
# pywinpty                      0.5.5
# PyYAML                        5.1.1
# pyzmq                         18.0.0
# QtAwesome                     0.5.7
# qtconsole                     4.5.2
# QtPy                          1.8.0
# queuelib                      1.5.0
# rasa-sdk                      1.1.0
# redis                         3.2.1
# regex                         2018.7.11
# requests                      2.22.0
# requests-toolbelt             0.9.1
# rocketchat-API                0.6.34
# rope                          0.14.0
# ruamel-yaml                   0.15.46
# ruamel.yaml                   0.15.100
# s3transfer                    0.2.0
# sanic-jwt                     1.3.2
# scikit-learn                  0.21.2
# scipy                         1.3.0
# Scrapy                        1.6.0
# seaborn                       0.9.0
# selenium                      3.141.0
# Send2Trash                    1.5.0
# service-identity              18.1.0
# setuptools                    41.0.1
# simplejson                    3.16.0
# six                           1.12.0
# sklearn-crfsuite              0.3.6
# slackclient                   1.3.2
# smart-open                    1.8.3
# snowballstemmer               1.9.0
# sortedcontainers              2.1.0
# soupsieve                     1.8
# spacy                         2.0.12
# SpeechRecognition             3.8.1
# Sphinx                        2.1.2
# sphinxcontrib-applehelp       1.0.1
# sphinxcontrib-devhelp         1.0.1
# sphinxcontrib-htmlhelp        1.0.2
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.2
# sphinxcontrib-serializinghtml 1.1.3
# spyder                        3.3.6
# spyder-kernels                0.5.1
# statsmodels                   0.10.0
# tabulate                      0.8.3
# tensorboard                   1.13.1
# tensorflow                    1.13.2
# tensorflow-estimator          1.13.0
# termcolor                     1.1.0
# terminado                     0.8.2
# terminaltables                3.1.0
# testpath                      0.4.2
# thinc                         6.10.3
# toolz                         0.10.0
# torch                         1.0.1
# torchvision                   0.2.2.post3
# tornado                       6.0.3
# tqdm                          4.32.1
# traitlets                     4.3.2
# twilio                        6.29.1
# Twisted                       19.2.0
# typed-ast                     1.4.0
# tzlocal                       2.0.0
# ujson                         1.35
# urllib3                       1.24.2
# w3lib                         1.20.0
# watermark                     1.8.1
# wcwidth                       0.1.7
# webencodings                  0.5.1
# webexteamssdk                 1.1.1
# websocket-client              0.54.0
# Werkzeug                      0.15.5
# wheel                         0.33.4
# widgetsnbextension            3.5.0
# win-inet-pton                 1.1.0
# wincertstore                  0.2
# wrapt                         1.10.11
# zipp                          0.5.1
# zope.interface                4.6.0
# Note: you may need to restart the kernel to use updated packages.
